# %% [markdown]
# <a href="https://colab.research.google.com/github/SakshiSodmise/Projects/blob/main/Mental_Health_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Depression
depression_responses = [
    "I'm really sorry to hear that you're feeling this way. Remember that you're not alone, and there are people who care about you and want to support you through this difficult time.",
    "I understand that living with depression can be incredibly challenging. It takes courage to reach out and share your feelings. It's important to seek professional help, as there are treatments available that can make a difference in your life.",
    "I'm here for you, and I want you to know that your feelings are valid. Depression can be overwhelming, but with the right support and treatment, it is possible to find relief. It's essential to reach out to a mental health professional who can guide you on your journey towards healing.",
    "I'm really sorry to hear that you're struggling with depression. It's important to remember that asking for help is a sign of strength, and reaching out to a mental health professional can provide you with the support and guidance you need. You don't have to face this alone.",
    "I'm so sorry to hear that you're experiencing depression. It's important to reach out to a mental health professional who can help you navigate through this challenging time. Remember that seeking support is a brave and important step towards finding relief and building a brighter future."
]

depression_suggestions = [
    """1)Seek professional help: Reach out to a mental health professional who can assess your condition and provide appropriate treatment options such as therapy, counseling, or medication.
        2)Prioritize self-care: Focus on activities that promote your well-being, such as maintaining a healthy routine, engaging in regular exercise, practicing relaxation techniques, and ensuring you get enough restful sleep.
        3)Build a support network: Reach out to friends, family, or support groups who can provide a listening ear and emotional support. Surrounding yourself with positive and understanding individuals can make a significant difference in managing depression.""",
    """1)Engage in therapeutic activities: Consider activities that can improve your mood and well-being, such as engaging in hobbies, practicing mindfulness or meditation, journaling, or creative outlets like art or music.
       2)Create a structured routine: Establishing a daily routine can provide a sense of stability and purpose. Plan out your day with achievable tasks and activities, including self-care practices and meaningful social interactions.
       3_Challenge negative thoughts: Work on identifying negative thought patterns and replacing them with positive and realistic thoughts. Cognitive-behavioral therapy techniques can be helpful in reframing negative thinking and promoting a more positive mindset.""",
    """1)Explore alternative therapies: Alongside professional help, consider complementary therapies such as acupuncture, yoga, or aromatherapy. While not a substitute for evidence-based treatments, they can complement your overall well-being.
       2)Focus on nutrition: A balanced diet rich in fruits, vegetables, whole grains, and lean proteins can support your mental health. Consider consulting a nutritionist or incorporating mood-boosting foods like omega-3 fatty acids (found in fish) and foods rich in B vitamins.
       3)Practice self-compassion and self-acceptance: Be patient with yourself and recognize that healing takes time. Embrace self-compassion by treating yourself with kindness and understanding, and practice self-acceptance by embracing your strengths and imperfections.""",
    """1)Establish a support system: Reach out to a trusted friend or family member who can provide support and be a listening ear. Opening up about your feelings can help alleviate the burden of depression.
       2)Set achievable goals: Start small by setting realistic goals for yourself. Break down larger tasks into manageable steps to avoid feeling overwhelmed, and celebrate even small victories along the way.
       3)Incorporate physical activity: Engage in regular physical exercise, as it can have a positive impact on your mood and overall well-being. Consider activities like walking, jogging, dancing, or joining a sports club to make it more enjoyable.""",
    """1)Practice relaxation techniques: Learn and incorporate relaxation techniques such as deep breathing exercises, progressive muscle relaxation, or guided imagery. These can help reduce stress and promote a sense of calm.
       2)Limit exposure to negative influences: Identify triggers or negative influences in your life, such as certain people, environments, or social media, and make an effort to limit your exposure to them. Surround yourself with positivity and supportive influences.
       3)Explore mindfulness and meditation: Consider practicing mindfulness and meditation techniques, which can help you cultivate awareness of the present moment and develop coping strategies for managing depressive symptoms. There are various apps, online resources, and guided meditations available to support your journey."""
]

# Anxiety
anxiety_responses = [
    "I'm sorry to hear that you're dealing with anxiety. It can be incredibly overwhelming, but please know that you're not alone. There are many resources and strategies available to help manage anxiety and improve your well-being.",
    "I understand that living with anxiety can be really tough. It's important to remember that you're not defined by your anxiety and that there are effective treatments and coping mechanisms available. Don't hesitate to reach out to a mental health professional who can provide you with the support you need.",
    "I'm here for you, and I want you to know that your feelings are valid. Anxiety can be challenging, but there are steps you can take to manage it. Remember to prioritize self-care, practice relaxation techniques, and consider seeking professional help to develop personalized strategies for coping with your anxiety.",
    "I'm really sorry to hear that you're struggling with anxiety. It's important to reach out for support, as you don't have to face it alone. Connecting with a mental health professional can provide you with tools and techniques to better manage your anxiety and improve your overall well-being.",
    "I'm so sorry to hear that you're experiencing anxiety. It's essential to remember that anxiety is a common condition, and there is help available. Reach out to a mental health professional who can assist you in developing a personalized plan to address your anxiety and regain control of your life."
]

anxiety_suggestions = [
    """1)Seek professional help: Consult with a mental health professional, such as a therapist or psychiatrist, who can provide an accurate diagnosis and develop a treatment plan tailored to your specific needs, which may include therapy, medication, or a combination of both.
       2)Practice deep breathing and relaxation techniques: Learn and incorporate deep breathing exercises, progressive muscle relaxation, or guided imagery to help calm your mind and body during anxious moments.
       3)Engage in regular physical exercise: Engaging in physical activity releases endorphins, which can improve your mood and reduce anxiety. Aim for at least 30 minutes of moderate exercise most days of the week.""",
    """1)Challenge negative thoughts: Identify and challenge negative or irrational thoughts that contribute to your anxiety. Practice reframing those thoughts into more realistic and positive ones to help alleviate anxiety.
       2)Establish a consistent sleep routine: Prioritize quality sleep by creating a soothing bedtime routine and maintaining a regular sleep schedule. Sufficient rest can help regulate emotions and reduce anxiety.
       3)Limit caffeine and alcohol consumption: Stimulants like caffeine can exacerbate anxiety symptoms, so consider reducing your intake. Similarly, alcohol may provide temporary relief but can worsen anxiety in the long run, so consume it in moderation or avoid it altogether.""",
    """1)Practice self-care: Engage in activities that promote self-care and stress reduction, such as taking regular breaks, pursuing hobbies you enjoy, spending time in nature, or practicing mindfulness and self-compassion.
       2)Build a support network: Share your feelings with trusted friends or family members who can provide emotional support. Consider joining support groups or seeking online communities where you can connect with others who understand what you're going through.
       3)Develop healthy coping mechanisms: Find healthy ways to manage stress and anxiety, such as journaling, listening to calming music, engaging in creative outlets like art or writing, or practicing yoga or meditation. Experiment with different techniques to find what works best for you.""",
    """1)Establish a structured routine: Create a daily schedule that includes regular activities, breaks, and self-care practices. Having a routine can provide a sense of stability and predictability, which can help reduce anxiety.
       2)Practice time management: Break tasks into smaller, manageable steps, and prioritize them based on importance. By organizing your time effectively, you can minimize the feeling of being overwhelmed and better manage anxiety associated with deadlines or commitments.
       3)Set boundaries: Learn to say no when necessary and establish healthy boundaries in relationships and responsibilities. Setting realistic limits can prevent feelings of being overloaded and reduce anxiety levels.""",
    """1)Monitor and manage your thoughts: Pay attention to your thought patterns and notice when negative or anxious thoughts arise. Use techniques like cognitive restructuring or positive affirmations to challenge and replace them with more helpful and realistic thoughts.
       2)Incorporate relaxation techniques into your daily routine: Dedicate time each day for relaxation exercises, such as deep breathing, progressive muscle relaxation, or guided imagery. Regular practice can help reduce anxiety and promote overall well-being.
       3)Prioritize self-care and stress reduction: Engage in activities that help you unwind and recharge, such as taking baths, practicing self-care rituals, listening to calming music, or engaging in hobbies that bring you joy. Making self-care a priority can help alleviate anxiety and improve your overall mental health."""
]

# Obsessive compulsive disorder
ocd_responses = [
    "I'm really sorry to hear that you're dealing with OCD. It can be a challenging condition, but it's important to know that there is hope and support available. Seeking professional help and learning effective coping strategies can make a significant difference in managing OCD symptoms.",
    "I understand that living with OCD can be incredibly distressing. Remember that you're not alone in this journey. There are mental health professionals who specialize in treating OCD and can provide you with guidance and support to help you navigate through the challenges.",
    "I'm here to support you through your struggles with OCD. It's important to remember that OCD is a medical condition and not a reflection of your character. Seeking treatment from a qualified mental health professional can help you develop coping mechanisms and strategies to manage your symptoms and improve your quality of life.",
    "I'm really sorry to hear that you're experiencing OCD. It's important to know that there are effective treatments available, including therapy and medication, that can help you gain control over your symptoms. Remember that reaching out for support is a brave step towards finding relief and improving your well-being.",
    "I'm so sorry to hear that you're dealing with OCD. It can be incredibly challenging, but please know that there is hope for recovery. Connect with a mental health professional who specializes in OCD treatment to receive the support and guidance you need. With the right strategies and support, you can learn to manage your OCD and live a fulfilling life."
]

ocd_suggestions = [
    """1)Seek professional help: Consult with a mental health professional experienced in treating OCD, such as a therapist or psychiatrist. They can provide an accurate diagnosis, develop a personalized treatment plan, and guide you through evidence-based therapies like Cognitive-Behavioral Therapy (CBT) or Exposure and Response Prevention (ERP).
       2)Practice exposure and response prevention: ERP is a highly effective treatment for OCD. Work with a therapist to gradually expose yourself to feared situations or triggers while resisting the urge to engage in compulsive behaviors. Over time, this can help reduce anxiety and break the cycle of OCD.
       3)Build a support system: Reach out to loved ones who can provide understanding and support during your OCD journey. Consider joining support groups or online communities where you can connect with others who share similar experiences.""",
    """1)Challenge obsessive thoughts: Learn to identify and challenge the irrational thoughts that fuel OCD. Work with a therapist to develop cognitive strategies that help reframe these thoughts and reduce their power over you.
       2)Establish a structured routine: Creating a structured daily routine can provide a sense of stability and control. Make sure to include activities that promote self-care, relaxation, and stress reduction.
       3)Practice self-compassion: Be kind and patient with yourself. Remember that OCD is a medical condition and not a personal failing. Treat yourself with understanding and practice self-compassion throughout your recovery process.""",
    """1)Learn and implement relaxation techniques: Practice relaxation techniques such as deep breathing exercises, meditation, or mindfulness. These techniques can help reduce overall anxiety levels and provide a sense of calm when OCD symptoms arise.
       2)Identify and avoid triggers: Pay attention to situations, people, or environments that trigger your OCD symptoms. When possible, try to minimize exposure to these triggers or develop coping strategies to navigate them effectively.
       3)Engage in regular exercise: Physical activity has been shown to have a positive impact on mental health. Engaging in regular exercise can help reduce anxiety and stress, and promote overall well-being.""",
    """1)Create a safety hierarchy: Work with a therapist to create a hierarchy of feared situations or objects related to your OCD obsessions. Gradually expose yourself to these situations or objects, starting with the least distressing and gradually progressing to more challenging ones, while resisting the urge to perform compulsions.
       2)Practice self-monitoring: Keep a journal or use a mobile app to track your OCD symptoms, triggers, and patterns. This self-monitoring can help you gain insights into your condition, identify patterns, and work with your therapist to develop targeted strategies for managing OCD.
       3)Educate yourself about OCD: Learn about the nature of OCD, its underlying mechanisms, and evidence-based treatments. Understanding your condition can empower you to make informed decisions about your treatment and actively participate in your recovery.""",
    """1)Minimize reassurance-seeking behaviors: Seeking reassurance from others is a common compulsion in OCD. Practice reducing or eliminating these behaviors, as they can reinforce obsessions and perpetuate the cycle of OCD. Instead, work on developing self-reassurance techniques and coping strategies.
       2)Implement organization and planning strategies: Develop effective organizational systems and planning techniques to help manage uncertainty and reduce anxiety. Breaking tasks into smaller, manageable steps and creating clear routines can help alleviate OCD-related stress.
       3)Take care of your overall well-being: Prioritize self-care activities that promote your overall well-being, such as maintaining a balanced diet, getting enough sleep, engaging in enjoyable activities, and practicing relaxation techniques. Taking care of yourself holistically can support your recovery from OCD."""
]

# Bipolar Disorder
bipolar_responses = [
    "I'm really sorry to hear that you're dealing with bipolar disorder. It can be a complex condition, but please know that there is support and treatment available to help you manage it. It's important to reach out to a mental health professional who can provide you with the guidance and resources you need.",
    "I understand that living with bipolar disorder can be challenging and overwhelming at times. Remember that you are not defined by your diagnosis, and with the right treatment and support, it is possible to lead a fulfilling life. Reach out to a mental health professional who can work with you to develop an effective treatment plan.",
    "I'm here for you, and I want you to know that your experiences and feelings are valid. Bipolar disorder can be difficult to navigate, but you don't have to face it alone. Connect with a mental health professional who specializes in bipolar disorder to receive the support, medication, and therapy that can help you manage your symptoms.",
    "I'm really sorry to hear that you're experiencing bipolar disorder. It's important to remember that bipolar disorder is a medical condition, and with proper treatment, many people are able to lead fulfilling lives. Seek out a mental health professional who can provide you with a comprehensive treatment plan and support system.",
    "I'm so sorry to hear that you're dealing with bipolar disorder. It can be a challenging condition, but there is hope for stability and well-being. Remember that seeking help from a mental health professional is an important step towards managing your symptoms and finding the right strategies and medications to support your overall mental health."
]

bipolar_suggestions =[
    """1)Seek professional help: It is essential to consult with a mental health professional experienced in treating bipolar disorder, such as a psychiatrist or psychologist. They can accurately diagnose your condition, develop a treatment plan, and prescribe appropriate medication if necessary.
       2)Establish a daily routine: Maintaining a regular daily routine can provide stability and help manage bipolar symptoms. Set consistent sleep and wake times, prioritize regular meals, and incorporate activities that promote self-care and stress reduction.
       3)Educate yourself and loved ones: Learn about bipolar disorder to better understand its symptoms, triggers, and treatment options. Share this knowledge with your loved ones, as their support and understanding can be crucial in managing bipolar disorder effectively.""",
    """1)Attend therapy: Engage in therapy, such as Cognitive-Behavioral Therapy (CBT) or psychoeducation, which can help you develop coping strategies, manage mood fluctuations, and improve overall well-being. Therapy can also provide a safe space to explore and address underlying issues related to bipolar disorder.
       2)Build a support network: Surround yourself with a supportive network of friends, family, or support groups who understand bipolar disorder. Having a support system can provide emotional support, encouragement, and understanding during both manic and depressive episodes.
       3)Practice medication management: If prescribed medication for bipolar disorder, adhere to your treatment plan and regularly communicate with your healthcare provider. Proper medication management is crucial for stabilizing moods and preventing relapses.""",
    """1)Monitor and manage mood triggers: Pay attention to factors that may trigger mood episodes, such as sleep disruptions, stress, or substance use. Develop strategies to minimize exposure to these triggers and implement healthy coping mechanisms when faced with them.
       2)Practice self-care: Prioritize self-care activities that promote mental and emotional well-being, such as engaging in regular exercise, getting sufficient sleep, practicing relaxation techniques, and pursuing hobbies or activities you enjoy.
       3)Develop a crisis plan: Collaborate with your mental health professional to create a crisis plan that outlines steps to take during manic or depressive episodes. This plan may include emergency contacts, coping strategies, and reminders of when to seek professional help.""",
    """1)Maintain a mood journal: Keep a mood journal to track your mood fluctuations, energy levels, and any triggering events or patterns. This can help you identify patterns, recognize early warning signs of mood episodes, and make proactive adjustments to your treatment plan.
       2)Communicate openly with your support system: Regularly communicate with your loved ones about your experiences and needs. Inform them about warning signs or triggers that they can help you identify and address, and involve them in your treatment plan if you feel comfortable doing so.
       3)Avoid excessive alcohol or substance use: Substance use can worsen bipolar symptoms and interfere with the effectiveness of medications. Minimize or avoid alcohol and illicit substances to maintain stability and support your mental health.""",
    """1)Develop a healthy lifestyle: Focus on maintaining a balanced lifestyle that includes regular exercise, a nutritious diet, and sufficient sleep. Healthy lifestyle habits can contribute to mood stability and overall well-being.
       2)Practice stress management: Implement stress reduction techniques such as deep breathing exercises, meditation, yoga, or engaging in hobbies or activities that help you relax and unwind. Managing stress effectively can help prevent mood episodes and support your mental health.
       3)Involve loved ones in treatment: Encourage your loved ones to educate themselves about bipolar disorder and involve them in your treatment journey. Having their understanding, support, and involvement in therapy sessions or doctor appointments can strengthen your overall support system."""
]

# Post-Traumatic Stress Disorder (PTSD)
ptsd_responses = [
    "I'm sorry to hear that you're dealing with PTSD. Remember, healing is possible with the right support.",
    "It's important to prioritize your safety and seek professional help for trauma processing.",
    "Understanding your triggers and developing grounding techniques can help manage PTSD symptoms.",
    "Consider trauma-focused therapy, such as EMDR or cognitive-behavioral therapy (CBT), for treatment.",
    "Connecting with other trauma survivors or support groups can provide valuable support and validation."
]

ptsd_suggestions =[
    """1)Seek professional help: It's important to consult with a mental health professional experienced in treating PTSD, such as a therapist or psychiatrist. They can provide an accurate diagnosis, develop a personalized treatment plan, and guide you through evidence-based therapies like Cognitive Processing Therapy (CPT) or Eye Movement Desensitization and Reprocessing (EMDR).
       2)Practice self-care: Prioritize self-care activities that promote your overall well-being, such as engaging in regular exercise, getting enough sleep, practicing relaxation techniques like deep breathing or meditation, and engaging in activities that bring you joy.
       3)Build a support network: Reach out to trusted friends, family members, or support groups who can provide understanding and emotional support. Connecting with others who have experienced similar trauma can help you feel less isolated and provide a sense of validation and community.""",
    """1)Establish a routine: Creating a structured daily routine can help provide stability and predictability, which can be particularly beneficial for managing symptoms of PTSD. Include activities that promote self-care, relaxation, and healthy coping strategies within your routine.
       2)Identify and manage triggers: Recognize the triggers or situations that worsen your PTSD symptoms and develop strategies to cope with them effectively. This may involve avoiding certain triggers when possible, using grounding techniques, or engaging in relaxation exercises during triggering situations.
       3)Practice grounding techniques: Grounding techniques can help bring your focus back to the present moment and reduce anxiety or distressing thoughts. Techniques like deep breathing, mindfulness exercises, or engaging your senses (such as focusing on the feeling of your feet on the ground) can be helpful in managing PTSD symptoms.""",
    """1)Educate yourself about PTSD: Learn about the symptoms, causes, and treatment options for PTSD. Understanding the nature of PTSD can help you better cope with your symptoms and make informed decisions about your treatment.
       2)Consider trauma-focused therapy: Trauma-focused therapies, such as CPT or EMDR, can help process traumatic experiences, challenge negative thoughts and beliefs associated with the trauma, and reduce PTSD symptoms. Discuss these options with a qualified therapist to determine the most suitable approach for you.
       3)Utilize relaxation techniques: Practice relaxation techniques regularly to help manage symptoms of anxiety and stress associated with PTSD. Deep breathing exercises, progressive muscle relaxation, guided imagery, or meditation can help promote a sense of calm and reduce the intensity of PTSD symptoms.""",
    """1)Engage in creative outlets: Explore creative activities that allow you to express yourself and process your emotions related to the trauma. This could include writing in a journal, painting, drawing, playing music, or engaging in other forms of art therapy that can help you communicate and release emotions in a non-verbal way.
       2)Practice self-compassion: Be gentle and patient with yourself as you navigate your healing journey. Recognize that healing takes time and that it is normal to experience ups and downs. Treat yourself with kindness and self-compassion as you work towards recovery.
       3)Develop safety strategies: Work with a therapist to develop safety strategies that help you feel secure and in control during moments of anxiety or distress. This might involve creating a safety plan, identifying safe spaces or people to turn to, or practicing self-soothing techniques that provide comfort during triggering situations.""",
    """1)Engage in physical activity: Regular exercise can have a positive impact on mental health, including PTSD symptoms. Engaging in activities such as walking, jogging, swimming, or yoga can help reduce anxiety, improve mood, and promote overall well-being.
       2)Explore support groups: Consider joining support groups specifically designed for individuals with PTSD. These groups provide a supportive and understanding environment where you can connect with others who have had similar experiences, share coping strategies, and gain valuable insights and encouragement.
       3)Practice stress management techniques: Incorporate stress management techniques into your daily routine to reduce overall stress levels. This can include activities such as deep breathing exercises, progressive muscle relaxation, practicing mindfulness, or engaging in hobbies and activities that bring you joy and relaxation."""
]

# Schizophrenia
schizophrenia_responses = [
    "I'm really sorry to hear that you're living with schizophrenia. It's important to know that you're not alone and that there are resources and treatments available to support you. Connect with a mental health professional who specializes in schizophrenia to receive the guidance and care you need.",
    "I understand that living with schizophrenia can be challenging and overwhelming. It's important to remember that you are more than your diagnosis, and with the right support and treatment, it is possible to manage symptoms and lead a fulfilling life. Seek out a mental health professional who can provide you with personalized strategies and therapies.",
    "I'm here for you, and I want you to know that your experiences and feelings are valid. Schizophrenia can be a complex condition, but you don't have to face it alone. Reach out to a mental health professional who can provide you with the necessary support and help you navigate through the challenges of living with schizophrenia.",
    "I'm really sorry to hear that you're experiencing schizophrenia. It's important to remember that schizophrenia is a treatable condition, and with the right treatment plan, many individuals with schizophrenia are able to lead fulfilling lives. Connect with a mental health professional who can guide you through the process of managing your symptoms and finding stability.",
    "I'm so sorry to hear that you're dealing with schizophrenia. It's important to seek professional help from a mental health expert who specializes in schizophrenia to receive the support, medication, and therapy that can assist you in managing your symptoms. Remember that you are not defined by your diagnosis, and there is hope for managing your condition and improving your overall well-being."
]

schizophrenia_suggestions = [
    """1)Seek professional help: It is crucial to consult with a mental health professional experienced in treating schizophrenia, such as a psychiatrist or psychologist. They can provide an accurate diagnosis, develop an individualized treatment plan, and prescribe appropriate medication if necessary.
       2)Engage in therapy: Participate in therapy sessions, such as cognitive-behavioral therapy (CBT) or family therapy, which can help you manage symptoms, enhance coping skills, improve communication, and strengthen relationships.
       3)Establish a support system: Build a network of supportive individuals who can provide understanding, encouragement, and assistance. This can include family members, friends, support groups, or advocacy organizations specifically focused on schizophrenia.""",
    """1)Adhere to medication regimen: Take prescribed medications as directed by your healthcare provider. Medication plays a crucial role in managing symptoms and reducing the frequency and severity of episodes. Regular communication with your healthcare provider is essential to monitor and adjust medication as needed.
       2)Manage stress: Develop stress management techniques, such as practicing relaxation exercises, engaging in mindfulness or meditation, and participating in activities that promote relaxation and emotional well-being. Minimizing stress can help prevent symptom exacerbation.
       3)Maintain a healthy lifestyle: Focus on maintaining a balanced lifestyle that includes regular exercise, a nutritious diet, sufficient sleep, and avoiding alcohol or illicit substances. These factors can support overall well-being and contribute to managing schizophrenia symptoms.""",
    """1)Educate yourself and loved ones: Learn about schizophrenia to better understand its symptoms, causes, and treatment options. Educate your loved ones about the condition as well, as their support and understanding can play a vital role in managing symptoms and reducing stigma.
       2)Create a structured routine: Establishing a structured daily routine can provide a sense of stability and predictability, which can be beneficial for individuals with schizophrenia. Include activities such as medication management, self-care, social interactions, and engaging in meaningful and enjoyable pursuits.
       3)Develop coping strategies: Work with a therapist to develop coping strategies specific to your symptoms and challenges. These may include identifying early warning signs, practicing grounding techniques, utilizing positive self-talk, and implementing problem-solving skills to address daily life challenges.""",
    """1)Engage in psychoeducation: Participate in psychoeducational programs or workshops designed to provide information and skills related to schizophrenia management. These programs can offer valuable insights, education about medication, strategies for managing symptoms, and resources for support.
       2)Foster a supportive living environment: Create a supportive and understanding living environment by involving family members or roommates in your treatment plan, educating them about schizophrenia, and establishing open communication. Encourage their involvement in therapy sessions or support groups if appropriate.
       3)Explore vocational and educational opportunities: Engage in vocational or educational activities that match your interests and abilities. Having a sense of purpose and engagement in meaningful activities can contribute to overall well-being and recovery.""",
    """1)Monitor and manage symptoms: Stay vigilant about your symptoms and communicate any changes or concerns with your healthcare provider. Keep a symptom journal to track your experiences, triggers, and response to medication or treatment, which can help inform adjustments to your treatment plan.
       2)Implement self-care practices: Prioritize self-care activities that support your mental and emotional well-being, such as practicing relaxation techniques, engaging in hobbies or activities you enjoy, spending time in nature, or connecting with supportive individuals who can provide a listening ear.
       3)Engage in peer support: Seek out peer support groups or online communities specifically for individuals with schizophrenia. Connecting with others who share similar experiences can provide a sense of belonging, reduce isolation, and offer a platform for sharing coping strategies and insights."""
]
# Eating Disorders
eating_disorder_responses = [
    "I'm sorry to hear that you're struggling with an eating disorder. Remember, recovery is possible with support.",
    "It's important to seek professional help to address the underlying issues related to your eating disorder.",
    "Recognizing triggers and developing coping mechanisms can help manage disordered eating behaviors.",
    "Consider therapy options such as Cognitive-Behavioral Therapy (CBT) or Dialectical Behavior Therapy (DBT) for treatment.",
    "Building a strong support network of loved ones and professionals who understand eating disorders is crucial."
]

eating_disorder_suggestions = [
    "Reach out to a registered dietitian who specializes in eating disorders for guidance on developing a healthy relationship with food.",
    "Practice self-compassion and challenge negative thoughts and beliefs about your body and self-worth.",
    "Engage in activities that promote self-care and self-expression outside of your eating disorder.",
    "Consider joining support groups or online communities where you can connect with others who are going through similar experiences.",
    "Develop a meal plan that focuses on balanced nutrition and regular eating patterns under the guidance of a healthcare professional.",
    "Explore alternative coping mechanisms such as creative outlets, journaling, or mindfulness practices."
]

# Substance Use Disorders
substance_use_disorder_responses = [
    "I'm really sorry to hear that you're struggling with substance use disorders. It takes courage to acknowledge and reach out for help. Remember that recovery is possible, and there are professionals who specialize in addiction treatment and can provide you with the support you need.",
    "I understand that living with substance use disorders can be incredibly challenging. It's important to know that you're not alone, and there are resources available to help you on your journey to recovery. Reach out to a substance abuse counselor or treatment center to receive the guidance and support you deserve.",
    "I'm here for you, and I want you to know that seeking help is a brave and important step towards overcoming substance use disorders. Remember that recovery is a process, and there are evidence-based treatments and support groups that can assist you in building a healthier and fulfilling life.",
    "I'm really sorry to hear that you're experiencing substance use disorders. It's important to reach out to a professional who can help you navigate through the challenges and provide you with the tools and strategies to overcome addiction. Remember that with the right support, determination, and treatment, you can achieve a life free from substance use.",
    "I'm so sorry to hear that you're dealing with substance use disorders. It's important to know that there is hope for recovery, and you deserve support and understanding. Reach out to a mental health professional or a local support group to connect with others who have similar experiences and to access resources that can guide you towards a healthier and happier life."
]

substance_use_disorder_suggestions = [
    """1)Seek professional help: Consult with a healthcare professional or addiction specialist who can provide a comprehensive assessment, diagnosis, and treatment plan tailored to your specific needs. They can guide you through evidence-based treatments such as therapy, counseling, and medication-assisted treatment if appropriate.
       2)Build a support network: Surround yourself with a supportive network of friends, family members, or support groups who understand and can provide encouragement during your recovery journey. Consider joining mutual support groups like Alcoholics Anonymous (AA) or Narcotics Anonymous (NA) to connect with others who are going through similar experiences.
       3)Develop healthy coping mechanisms: Learn and practice healthy coping mechanisms to manage stress and emotional triggers. This can include engaging in physical exercise, mindfulness meditation, pursuing hobbies or creative outlets, and seeking professional help to address underlying emotional or psychological issues.""",
    """1)Establish a structured routine: Create a structured daily routine that includes healthy habits and activities. This can help provide stability and a sense of purpose, reducing the likelihood of turning to substance use as a coping mechanism. Set regular sleep patterns, plan nutritious meals, and schedule time for self-care and meaningful activities.
       2)Avoid triggers and high-risk situations: Identify and avoid triggers or situations that may tempt you to use substances. This may involve changing your social circle, avoiding specific places or events, and developing strategies to manage cravings and urges when they arise.
       3)Engage in therapy or counseling: Participate in therapy or counseling sessions, such as cognitive-behavioral therapy (CBT) or motivational interviewing. These therapeutic approaches can help you explore the underlying factors contributing to substance use, develop healthier thought patterns and behaviors, and learn relapse prevention strategies.""",
    """1)Develop a relapse prevention plan: Collaborate with your treatment provider to create a relapse prevention plan. This plan should outline strategies for managing cravings, coping with triggers, and seeking support in times of need. Regularly review and update the plan to ensure its effectiveness.
       2)Attend support group meetings: Regularly attend support group meetings, such as AA, NA, or SMART Recovery, where you can share your experiences, learn from others, and receive support from individuals who have successfully maintained sobriety. Peer support can play a crucial role in long-term recovery.
       3)Practice self-care: Prioritize self-care activities that promote physical, emotional, and mental well-being. Engage in regular exercise, eat a balanced diet, get enough sleep, and engage in activities that bring you joy and relaxation. Taking care of yourself holistically can support your recovery journey.""",
    """1)Remove triggers and temptations: Rid your environment of substances, drug paraphernalia, and anything that reminds you of substance use. This can help reduce the likelihood of relapse and create a healthier living space.
       2)Engage in alternative therapies: Explore alternative therapies or holistic approaches that can complement traditional treatment methods. Examples include art therapy, music therapy, yoga, acupuncture, or mindfulness practices. These approaches can promote self-expression, stress reduction, and overall well-being.
       3)Practice stress management techniques: Develop healthy stress management techniques to cope with daily stressors without resorting to substance use. This may involve deep breathing exercises, mindfulness meditation, journaling, or engaging in activities that help you relax and unwind.""",
    """1)Educate yourself about addiction: Learn about the nature of addiction, including its effects on the brain and the recovery process. Understanding the science behind addiction can help you gain insight into your own experiences and provide motivation for change.
       2)Set realistic goals: Set realistic and achievable goals for your recovery. Break down the journey into smaller steps and celebrate milestones along the way. This can help you stay motivated and focused on your progress.
       3)Practice self-compassion: Be kind and patient with yourself throughout the recovery process. Recognize that setbacks may occur, but they do not define your journey. Treat yourself with compassion, forgiveness, and resilience as you work towards a healthier and substance-free life."""
]


# Attention-Deficit/Hyperactivity Disorder (ADHD)
adhd_responses = [
    "I'm really sorry to hear that you're living with ADHD. It's important to know that you're not alone, and there are strategies and resources available to help you manage your symptoms and thrive. Connect with a mental health professional who specializes in ADHD to receive the guidance and support you need.",
    "I understand that living with ADHD can be challenging, but please know that your experiences and feelings are valid. Remember that ADHD is a neurodevelopmental condition, and with the right support and strategies, you can learn to navigate its challenges and capitalize on your strengths. Reach out to professionals who can provide you with personalized tools and techniques.",
    "I'm here for you, and I want you to know that having ADHD does not define you as a person. It's important to seek support from mental health professionals who can help you develop coping mechanisms and strategies to manage your symptoms effectively. Remember that you have unique talents and abilities that can be harnessed with the right support.",
    "I'm really sorry to hear that you're experiencing ADHD. It's important to remember that ADHD is a common condition, and many successful individuals have learned to thrive with it. Seek out a mental health professional who specializes in ADHD to receive personalized strategies and interventions that can help you navigate challenges and reach your goals.",
    "I'm so sorry to hear that you're dealing with ADHD. It can be frustrating at times, but remember that you are not alone in this journey. Connect with a mental health professional who can provide you with guidance, support, and resources tailored to managing ADHD. With the right strategies and support, you can learn to navigate challenges and maximize your potential."
]

adhd_suggestions = [
    """1)Seek professional evaluation: Consult with a healthcare professional, such as a psychiatrist or psychologist, who specializes in ADHD diagnosis and treatment. A comprehensive evaluation can help determine if you have ADHD and guide the development of an appropriate treatment plan.
       2)Explore medication options: Discuss with your healthcare provider the potential benefits and risks of medication for managing ADHD symptoms. Medications like stimulants or non-stimulants may be prescribed to improve focus, attention, and impulse control.
       3)Develop organizational strategies: Implement strategies to improve organization and time management skills. This may involve using tools like planners, digital reminders, breaking tasks into smaller, manageable steps, and creating a structured environment to minimize distractions.""",
    """1)Learn about ADHD: Educate yourself about ADHD, including its symptoms, challenges, and available treatment options. Understanding the condition can empower you to develop effective strategies and advocate for your needs.
       2)Behavioral therapy: Consider participating in behavioral therapy, such as Cognitive-Behavioral Therapy (CBT) or behavioral coaching. These therapies can help you develop coping mechanisms, improve executive functioning skills, and address any accompanying emotional or behavioral challenges.
       3)Create a supportive environment: Establish an environment that supports focus and productivity. This can involve organizing your physical space, minimizing distractions, and implementing routines and structures that promote productivity and consistency.""",
    """1)Break tasks into manageable chunks: Break down tasks into smaller, more manageable steps to prevent overwhelm and improve focus. Prioritize tasks, set realistic deadlines, and utilize techniques like time blocking or creating to-do lists to stay organized and on track.
       2)Utilize assistive tools: Take advantage of assistive technologies and tools specifically designed for individuals with ADHD. These may include task management apps, noise-canceling headphones, focus-boosting apps, or tools that provide visual or auditory cues to aid in concentration.
       3)Engage in physical exercise: Regular physical exercise can help reduce hyperactivity, improve mood, and enhance overall cognitive function. Engaging in activities like walking, jogging, dancing, or yoga can help manage ADHD symptoms and improve overall well-being.""",
    """1)Implement strategies for time management: Use time management techniques like setting timers, creating schedules or routines, and breaking tasks into time-blocked intervals. Establishing structure and clear time boundaries can help with task completion and reduce procrastination.
       2)Practice mindfulness and relaxation techniques: Incorporate mindfulness and relaxation exercises into your daily routine. Techniques such as deep breathing, meditation, or progressive muscle relaxation can help calm the mind, reduce impulsivity, and improve focus.
       3)Seek support and join ADHD communities: Connect with others who have ADHD by joining support groups or online communities. Sharing experiences, strategies, and support with individuals who understand your challenges can be valuable for managing ADHD and reducing feelings of isolation.""",
    """1)Improve sleep habits: Prioritize getting enough quality sleep as it can significantly impact ADHD symptoms. Establish a consistent sleep schedule, create a relaxing bedtime routine, and create a sleep-friendly environment to optimize restful sleep.
       2)Utilize visual aids and reminders: Use visual aids, such as calendars, color-coded schedules, or reminder apps, to help with time management, task prioritization, and memory recall. Visual cues can assist in staying organized and on top of responsibilities.
       3)Develop self-care routines: Engage in self-care activities that promote relaxation, stress reduction, and overall well-being. This can include activities like regular exercise, engaging in hobbies, spending time in nature, practicing mindfulness, or seeking therapy to address any emotional challenges associated with ADHD."""
]
Suggestions_prompts = ["what should i do", "what can i do", "how can i cope","what else" , "advice","suggestion","more",
                       "suggest"]

greetings = ["hi", "hello", "hey", "greetings"]

farewells = ["goodbye", "bye", "take care", "farewell","stay hard!!"]

haalchaal_ques = ["how are you?",
            "how are you doing?",
            "whats up?"]
haalchaal=  [
            "Thank you for asking! Since I'm an AI chatbot, I don't have personal experiences. However, I'm here to assist you and provide support. How can I help you today?",
            "Hello! I'm here to chat and provide support. How can I assist you today? Feel free to share if there's anything specific on your mind or if you have any questions.",
            "I'm an AI chatbot, so I don't have emotions, but I'm ready to help you with any concerns or questions you may have. How can I assist you today?",
            "Thank you for asking. As a chatbot, I don't have feelings, but I'm here to assist you. How can I help you today?"
        ]

thanks_list = ["thanks", "thank you", "that's helpful", "thanks a lot"]
thanks_response = ["happy to help!", "any time!", "my pleasure"]

def get_luna_response(user_input, conversation_context):
    user_input = user_input.lower()

    if user_input in greetings:
        return random.choice(["Hello!", "Hi there!", "Greetings!"])

    if user_input in thanks_list:
        return random.choice(thanks_response)

    if user_input in haalchaal_ques:
        return random.choice(haalchaal)

    if conversation_context == "depression":
        if any(word in user_input for word in Suggestions_prompts):
            return random.choice(depression_suggestions)
        else:
            return random.choice(depression_responses)

    if conversation_context == "anxiety":
        if any(word in user_input for word in Suggestions_prompts):
            return random.choice(anxiety_suggestions)
        else:
            return random.choice(anxiety_responses)

    if conversation_context == "ocd":
        if any(word in user_input for word in Suggestions_prompts):
            return random.choice(ocd_suggestions)
        else:
            return random.choice(ocd_responses)

    if conversation_context == "bipolar":
        if any(word in user_input for word in Suggestions_prompts):
            return random.choice(bipolar_suggestions)
        else:
            return random.choice(bipolar_responses)

    if conversation_context == "ptsd":
        if any(word in user_input for word in Suggestions_prompts):
            return random.choice(ptsd_suggestions)
        else:
            return random.choice(ptsd_responses)

    if conversation_context == "schizophrenia":
        if any(word in user_input for word in Suggestions_prompts):
            return random.choice(schizophrenia_suggestions)
        else:
            return random.choice(schizophrenia_responses)

    if conversation_context == "eating_disorder":
        if any(word in user_input for word in Suggestions_prompts):
            return random.choice(eating_disorder_suggestions)
        else:
            return random.choice(eating_disorder_responses)

    if conversation_context == "substance_use_disorder":
        if any(word in user_input for word in Suggestions_prompts):
            return random.choice(substance_use_disorder_suggestions)
        else:
            return random.choice(substance_use_disorder_responses)

    if conversation_context == "adhd":
        if any(word in user_input for word in Suggestions_prompts):
            return random.choice(adhd_suggestions)
        else:
            return random.choice(adhd_responses)

    if user_input in farewells:
        return random.choice(farewells)

    return "I'm here to provide support and information on mental health. Feel free to ask any questions."


def start_conversation():
    print("Luna: Hi, how can I assist you today?")
    conversation_context = None

    while True:
        user_input = input("User: ")

        if conversation_context is None:
            if "depression" in user_input:
                conversation_context = "depression"
            elif "anxiety" in user_input:
                conversation_context = "anxiety"
            elif "ocd" in user_input or "obsessive-compulsive disorder" in user_input:
                conversation_context = "ocd"
            elif "bipolar" in user_input or "bipolar disorder" in user_input:
                conversation_context = "bipolar"
            elif "ptsd" in user_input or "post-traumatic stress disorder" in user_input:
                conversation_context = "ptsd"
            elif "schizophrenia" in user_input:
                conversation_context = "schizophrenia"
            elif "eating disorder" in user_input:
                conversation_context = "eating_disorder"
            elif "substance use disorder" in user_input or "addiction" in user_input:
                conversation_context = "substance_use_disorder"
            elif "adhd" in user_input or "attention-deficit/hyperactivity disorder" in user_input:
                conversation_context = "adhd"

        response = get_luna_response(user_input, conversation_context)
        print("Luna:", response)

        if user_input.lower() == "exit":
            print("Luna: Goodbye!")
            break


start_conversation()
